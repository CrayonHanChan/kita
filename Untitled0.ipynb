# %%
cd '/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026'
# Out:
# /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026

# %%
# !pwd
# Out:
# /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026

# %%
# !rm -rf .git
