# %% [markdown]
# #### 프로젝트 제목 : 파이썬 프로그래밍(자유 주제)
# - 이번 미니 프로젝트의 목적 : 단순한 코딩 기술을 넘어 데이터를 가치 있는 지식으로 변환하고, 실제 문제를 해결하는 실용적인 프로그램을 개발하는 것
# - 프로젝트를 진행하면서, 파이썬의 기본적인 사용법에 익숙해지고, 실제 문제를 해결하는 프로그램을 만드는 경험을 쌓게 될 것
# - 강사님의 프로젝트 평가는 11/10 (금)에 하게되고 1주일정도의 기간이 있음.
# - 지금까지 배웠던 파이썬의 내용을 복습하면서 실제로 가치가 있는 프로그램을 만들어 보는것이 중요한 포인트
#
# 1. 주제 선정
# - 프로젝트 제목 : 오늘 할 일 관리 프로그램
# - 이 프로젝트를 통해 기본적인 파이썬 작업을 다시 정리해보며 사용해볼 수 있으며, 사용자의 입력에 따라 데이터를 조작하는 방법을 익힐 수 있음
# - 주제 선정 이유와 개발 목표 : '오늘 할 일 관리 프로그램'은 정말 누구에게나 간편하고 쉽게 자신의 할 것들을 정리하고 또 목표를 세울수 있는 실용적인 프로그램으로 만들고 싶다. 특히 해야할 것들을 여러가지 입력 받았을 때, 할 일 목록을 만들어서 사용자가 쉽게 인식 할 수 있도록 개발할 수 있도록 하는 것이 목표.
#
# 2. 개발 전 기획 및 설계
# - 프로그램에서 사용자가 할 수 있는 작업에는 할 일 추가, 할 일 조회, 할 일 완료 체크 등.
# - 사용자가 할 일을 입력할 때, 할 일의 예상 소요시간 과 함께 입력하게 하여 할 일의 대한 리스트를 만들어 조회 하였을 때 사용자가 할 일을 구분하기 쉽게 개발.
# - 에러 처리, 사용자 함수로 정의, 코드를 간소화 하는 작업등을 통해 작업된 코드가 가독성이 좋아질 수 있게끔 개발.
# - 할 일을 저장하여 불러올수 있을 to_do 변수를 선언.
# - 개발하는 동안 각 기능별로 테스트를 통해 정상 작동을 확인.
# - sleep 을 import하여 time 함수 사용하는등 사용자가 프로그램을 실행했을 때 인식하기 쉽도록 개발.
# - datetime 을 import하여 할 일 목록을 수행 후의 시간을 사용자에게 출력.
#
# 3. 간단한 콘티
# - 예 : 1. 할 일 추가 2. 할 일 수정/삭제 3. 할 일 조회 4. 프로그램 종료 등의 메인메뉴를 만들고 여기에서 사용자가 선택해서 할 일을 관리 할 수 있게끔 만든다.
# - 예를 들어 1을 입력 하면 할 일의 제목과 그 일의 걸리는 시간을 입력 받아 딕셔너리에 저장. 그 후 목록을 사용자가 언제든 조회 하거나 수정할 수 있게끔 개발. 2를 입력하면 해당 내용을 수정할 수 있거나 삭제여부를 물어본다.
# - import datetime 을 사용. time() 함수를 사용해서 현재시간에 할 일의 소요 시간을 더해서 시간을 출력하여 만들기
#
# 4. 추가 아이디어
# - 할 일 리스트를 등록하고 조회, 수정 등의 기능 뿐만 아니라 사용자들이 니즈를 생각해서 이 프로그램을 정말 사용할 만한 기능을 넣어보자!
# - 할 일 추가 프로그램에서 -> 오늘의 해야 할 일을 효과적이고 시간적으로 잘 계획할 수 있는 프로그램으로 만들어보자! 가이드 형태
#
# 1. 할 일 리스트를 조회 할 떄 소요시간에 따라 오름/내림차순으로 출력하고 동기부여가 될만한 인용구를 넣어서 목록을 간결하게 보여주고 사용자에게 동기를 부여.
#
# 2. 할 일을 완료할때 (시간대의 맞는)점수를 얻고 점수에 따라서 뱃지를 획득 하는 시스템을 추가. 긴 시간의 할 일이면 점수는 높게 설정
#
# 3. 시간 관리에 대한 조언. 정말로 소요된 시간을 입력하고 그 다음에 예상 소요 시간과 비교 하여 사용자에게 조언.
# - 소요시간이 예상시간의 0.8~1.2배 라면.. 해당과 같이 출력
# - 소요시간이 짧게 걸렸던 이유를 적어보세요.(이를통해서 사용자가 점검을 할 수 있음)
# - 보너스 점수추가 1.5배
# - 동기 부여할 만한 응원문구 예) 앞으로 이렇게 더 열심히 !
# - 다음 할일을 하기 전에 스트레칭을 하거나 했던것을 복습하거나 다음 할 일로 갈 수 있습니다. 해당 일을 정리할 수 있습니다!
# - ================================================
#
# - 소요시간이 범위 밖이라면...
# - 소요시간이 {time}만큼 걸렸던 이유를 적어보세요.(이를통해서 사용자가 점검을 할 수 있음)
# - 보너스 점수 X
# - 실제 소요 시간 예상 소요 시간과 최대한 맞추는게 가장 좋은 예 입니다. 지속적으로 맞추려는 훈련을 통해서 본인의 작업 속도나 컨디션등 에 따라 예상 소요 시간을 조절할 수 있는 능력을 기른다면 본인의 일정을 컨트롤 할 수 있게끔 발전할 것입니다.

# %%
#한정현_1106-1110_프로젝트_오늘_할_일_관리_프로그램
print("오늘 할 일 관리 프로그램")
import sleep
import datetime
to_do = 
def to_do1_plus():
    if to_do = input()
    
def to_do2_minus():

    
def to_do3_info():
    
    
def end_to_do():    
    
    
def main_menu():
    while 1 :
        print("1. 할 일 추가하기")
        print("2. 할 일 수정/삭제하기")
        print("3. 할 일 조회하기")
        print("4. 프로그램 종료하기")
