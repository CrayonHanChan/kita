# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.1/749.1 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 56.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 57.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 85.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.0 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.5 MB/s eta 0:00:00

# %% [markdown]
# https://universe.roboflow.com/bnvs-co69a/semi_aug/dataset/2#

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="8llqVTheWtnyL2TQi9DI")
project = rf.workspace("bnvs-co69a").project("semi_aug")
version = project.version(2)
dataset = version.download("yolov8", location="/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.42, to fix: `pip install ultralytics==8.0.196`

# %%
# !cat /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/data.yaml
# Out:
# names:
# - budge circuit
# - circle
# - curve circuit
# - cut circuit
# - dot
# - edge circuit
# - fat circuit
# - line
# - scratch
# - short circuit
# - spot
# - thin circuit
# nc: 12
# roboflow:
#   license: CC BY 4.0
#   project: semi_aug
#   url: https://universe.roboflow.com/bnvs-co69a/semi_aug/dataset/2
#   version: 2
#   workspace: bnvs-co69a
# test: ../test/images
# train: /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/train/images
# val: /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/valid/images

# %%
# !pip install PyYAML -q

# %%
# yaml 파일을 학습이 가능하도록 경로 설정.
# key-value 데이터인 dict 데이터타입으로 data['train'], data['val'], data['nc'], data['names'] 에 넣어주는데,
# 가장 중요한 부분은 데이터 경로 설정임.

import yaml

data = { 'train' : '/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/train/images',
         'val' : '/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/valid/images',
         'test' : '/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/test/images',
         'names' : ['budge circuit', 'circle', 'curve circuit', 'cut circuit', 'dot', 'edge circuit', 'fat circuit', 'line', 'scratch', 'short circuit', 'spot', 'thin circuit'],
         'nc' : 12 }

with open('/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/data.yaml', 'w') as f:
  yaml.dump(data, f)


with open('/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/data.yaml', 'r') as f:
  data_yaml = yaml.safe_load(f)
  display(data_yaml)
# Out:
# {'names': ['budge circuit',
#   'circle',
#   'curve circuit',
#   'cut circuit',
#   'dot',
#   'edge circuit',
#   'fat circuit',
#   'line',
#   'scratch',
#   'short circuit',
#   'spot',
#   'thin circuit'],
#  'nc': 12,
#  'test': '/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/test/images',
#  'train': '/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/train/images',
#  'val': '/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/valid/images'}

# %%
# !cat /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/data.yaml
# Out:
# names:
# - budge circuit
# - circle
# - curve circuit
# - cut circuit
# - dot
# - edge circuit
# - fat circuit
# - line
# - scratch
# - short circuit
# - spot
# - thin circuit
# nc: 12
# test: /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/test/images
# train: /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/train/images
# val: /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/valid/images

# %%
# Load YOLOv8n

from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 136MB/s]

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
model.train(data='/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/data.yaml', epochs=100, patience=30, batch=32, imgsz=1024)
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 12
# {0: 'budge circuit', 1: 'circle', 2: 'curve circuit', 3: 'cut circuit', 4: 'dot', 5: 'edge circuit', 6: 'fat circuit', 7: 'line', 8: 'scratch', 9: 'short circuit', 10: 'spot', 11: 'thin circuit'}

# %%
from PIL import Image
from IPython.display import Image, clear_output
Image(filename='/content/runs/detect/train/train_batch0.jpg',width=1000)

# %%
Image(filename='/content/runs/detect/train/val_batch0_labels.jpg',width=1000)

# %%
results = model.predict(source='/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/valid/images/', save=True)
# Out:
# image 1/81 /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/valid/images/copydata10_jpg.rf.e0f3d4d305f0270839dd8d5ffbb25ba6.jpg: 1024x1024 2 lines, 12.5ms
# image 2/81 /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/valid/images/copydata11_jpg.rf.d28621cd1cbfa4cc06c5a6579ca8890c.jpg: 1024x1024 1 line, 1 scratch, 12.5ms
# image 3/81 /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/valid/images/copydata24_jpg.rf.7cbd1c8874b6122fd9d9d22aed6c5a9e.jpg: 1024x1024 5 curve circuits, 1 dot, 1 line, 12.4ms
# image 4/81 /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/semiconductor/data_691_2/valid/images/copydata25_jpg.rf.aacb7ec125adf2f8c7f3fe70a4d31333.jpg: 1024x1024 1 dot, 1 line, 12.4ms
# ...

# %%
print(type(results), len(results))
# Out:
# <class 'list'> 81

# %%
import glob
import random
from IPython.display import Image, display

image_name = random.choice(glob.glob('/content/runs/detect/train2/*.jpg'))
display(Image(filename=image_name,width=600,height=600))
