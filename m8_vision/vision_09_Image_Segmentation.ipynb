# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.1/749.1 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 49.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 63.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
import os
import zipfile

with zipfile.ZipFile('/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/images/test_image_dir.zip') as target_fle:
    target_fle.extractall('/content/test_image_dir')


print('test images = ', os.listdir('/content/test_image_dir'))
# Out:
# test images =  ['test2.jpg', 'test4.jpg', 'test1.jpg', 'test3.jpg']

# %% [markdown]
# # 테스트 이미지 display

# %%
from IPython.display import Image, clear_output
Image(filename='/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/images/test_image_dir/test1.jpg',width=500)

# %%
Image(filename='/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/images/test_image_dir/test2.jpg',width=500)

# %%
Image(filename='/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/images/test_image_dir/test3.jpg',width=500)

# %%
Image(filename='/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/images/test_image_dir/test4.jpg',width=500)

# %% [markdown]
# # Instance Segmentation (Python version)

# %%
from ultralytics import YOLO

model = YOLO('yolov8l-seg.pt')
# Out:
# ...
# 100%|██████████| 88.1M/88.1M [00:00<00:00, 308MB/s]

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %% [markdown]
# # test image prediction

# %%
results = model.predict(source='/content/test_image_dir/*.jpg', save=True)
# Out:
# image 1/4 /content/test_image_dir/test1.jpg: 544x640 1 laptop, 1 mouse, 2 keyboards, 1 cell phone, 102.1ms
# image 2/4 /content/test_image_dir/test2.jpg: 448x640 7 zebras, 1 giraffe, 81.3ms
# image 3/4 /content/test_image_dir/test3.jpg: 640x640 2 cups, 2 bowls, 2 sandwichs, 1 dining table, 77.2ms
# image 4/4 /content/test_image_dir/test4.jpg: 480x640 2 persons, 1 truck, 1 horse, 93.1ms
# Speed: 2.8ms preprocess, 88.4ms inference, 181.2ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/segment/predict

# %%
from IPython.display import Image

# 이미지 표시
Image(filename='/content/runs/segment/predict/test1.jpg', width=600)

# %%
Image(filename='/content/runs/segment/predict/test2.jpg', width=600)

# %%
Image(filename='/content/runs/segment/predict/test3.jpg', width=600)

# %%
Image(filename='/content/runs/segment/predict/test4.jpg', width=600)

# %% [markdown]
# Prediction (Inference)

# %%
results = model.predict(source='/content/test_image_dir/*.jpg', save=True)
# Out:
# image 1/4 /content/test_image_dir/test1.jpg: 544x640 1 laptop, 1 mouse, 2 keyboards, 1 cell phone, 16.5ms
# image 2/4 /content/test_image_dir/test2.jpg: 448x640 7 zebras, 1 giraffe, 14.8ms
# image 3/4 /content/test_image_dir/test3.jpg: 640x640 2 cups, 2 bowls, 2 sandwichs, 1 dining table, 14.1ms
# image 4/4 /content/test_image_dir/test4.jpg: 480x640 2 persons, 1 truck, 1 horse, 14.4ms
# Speed: 2.0ms preprocess, 14.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/segment/predict

# %%
import glob
import random
from IPython.display import Image, display

image_name = random.choice(glob.glob('/content/runs/segment/predict/*.jpg'))
display(Image(filename=image_name))
