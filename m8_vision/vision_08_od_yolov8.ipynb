# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.1/749.1 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 63.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 61.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 83.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.2 MB/s eta 0:00:00
# ...

# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/78.2 GB disk)

# %%
from PIL import Image

with Image.open('/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/images/test_image_dir/test1.jpg') as test_image:

    display(test_image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x516>

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
print(type(model.names), len(model.names))
print(model.names)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 248MB/s]
# <class 'dict'> 80
# ...

# %%
results = model.predict(source='/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/images/test_image_dir/test1.jpg', save=True)
# Out:
# image 1/1 /content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/images/test_image_dir/test1.jpg: 544x640 1 laptop, 1 mouse, 2 keyboards, 1 cell phone, 103.7ms
# Speed: 6.1ms preprocess, 103.7ms inference, 679.9ms postprocess per image at shape (1, 3, 544, 640)
# Results saved to runs/detect/predict

# %%
from IPython.display import Image, clear_output
Image(filename='/content/runs/detect/predict/test1.jpg',width=600)

# %%
results = model.predict(source='/content/drive/MyDrive/kdt_231026/m8_vision/images/test_image_dir/test2.jpg', save=True)
Image(filename='/content/runs/detect/predict/test2.jpg',width=600)
# Out:
# image 1/1 /content/drive/MyDrive/kdt_231026/m8_vision/images/test_image_dir/test2.jpg: 448x640 3 zebras, 1 giraffe, 114.2ms
# Speed: 2.6ms preprocess, 114.2ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict

# %%
results = model.predict(source='/content/drive/MyDrive/kdt_231026/m8_vision/images/test_image_dir/test3.jpg', save=True)
Image(filename='/content/runs/detect/predict/test3.jpg',width=600)
# Out:
# image 1/1 /content/drive/MyDrive/kdt_231026/m8_vision/images/test_image_dir/test3.jpg: 608x640 2 cups, 1 bowl, 2 sandwichs, 1 dining table, 113.4ms
# Speed: 3.4ms preprocess, 113.4ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 640)
# Results saved to runs/detect/predict

# %%
results = model.predict(source='/content/drive/MyDrive/kdt_231026/m8_vision/images/test_image_dir/test4.jpg', save=True)
Image(filename='/content/runs/detect/predict/test4.jpg',width=600)
# Out:
# image 1/1 /content/drive/MyDrive/kdt_231026/m8_vision/images/test_image_dir/test4.jpg: 480x640 3 persons, 1 truck, 1 horse, 112.8ms
# Speed: 2.4ms preprocess, 112.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict

# %% [markdown]
# Data Preparation
#
# Aquarium Dataset (custom data) 다운로드
#
# Public Dataset : https://public.roboflow.com/object-detection/aquarium/2

# %%
# !wget -O Aquarium_Data.zip  https://public.roboflow.com/ds/hQEYrvq08t?key=jncKr5vLkH # 강사님 주소
# !wget -O Aquarium_Data.zip https://public.roboflow.com/ds/mYFM78bVcC?key=1jqxjKWInK
# Out:
# --2024-04-03 01:32:43--  https://public.roboflow.com/ds/mYFM78bVcC?key=1jqxjKWInK
# Resolving public.roboflow.com (public.roboflow.com)... 151.101.1.195, 151.101.65.195
# Connecting to public.roboflow.com (public.roboflow.com)|151.101.1.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-regional-exports/5w20VzQObTXjJhTjq6kad9ubrm33/SjsZRQlmDqyawO3e26tc/2/yolov8.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20240403%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240403T013244Z&X-Goog-Expires=900&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
import zipfile

with zipfile.ZipFile('/content/Aquarium_Data.zip') as target_file:

    target_file.extractall('/content/Aquarium_Data/')

# %%
# !cat /content/Aquarium_Data/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 7
# names: ['fish', 'jellyfish', 'penguin', 'puffin', 'shark', 'starfish', 'stingray']
#
# roboflow:
#   workspace: brad-dwyer
#   project: aquarium-combined
#   version: 2
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/brad-dwyer/aquarium-combined/dataset/2

# %%
# !pip install PyYAML

# %%
# yaml 파일을 학습이 가능하도록 경로 설정.
# key-value 데이터인 dict 데이터타입으로 data['train'], data['val'], data['nc'], data['names'] 에 넣어주는데,
# 가장 중요한 부분은 데이터 경로 설정임.

import yaml

data = { 'train' : '/content/Aquarium_Data/train/images/',
         'val' : '/content/Aquarium_Data/valid/images/',
         'test' : '/content/Aquarium_Data/test/images',
         'names' : ['fish', 'jellyfish', 'penguin', 'puffin', 'shark', 'starfish', 'stingray'],
         'nc' : 7 }

with open('/content/Aquarium_Data/Aquarium_Data.yaml', 'w') as f:
  yaml.dump(data, f)


with open('/content/Aquarium_Data/Aquarium_Data.yaml', 'r') as f:
  aquarium_yaml = yaml.safe_load(f)
  display(aquarium_yaml)
# Out:
# {'names': ['fish',
#   'jellyfish',
#   'penguin',
#   'puffin',
#   'shark',
#   'starfish',
#   'stingray'],
#  'nc': 7,
#  'test': '/content/Aquarium_Data/test/images',
#  'train': '/content/Aquarium_Data/train/images/',
#  'val': '/content/Aquarium_Data/valid/images/'}

# %%
# !cat /content/Aquarium_Data/Aquarium_Data.yaml
# Out:
# names:
# - fish
# - jellyfish
# - penguin
# - puffin
# - shark
# - starfish
# - stingray
# nc: 7
# test: /content/Aquarium_Data/test/images
# train: /content/Aquarium_Data/train/images/
# val: /content/Aquarium_Data/valid/images/

# %%
# Load YOLOv8n

from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
model.train(data='/content/Aquarium_Data/Aquarium_Data.yaml', epochs=100, patience=30, batch=32, imgsz=416)
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 7
# {0: 'fish', 1: 'jellyfish', 2: 'penguin', 3: 'puffin', 4: 'shark', 5: 'starfish', 6: 'stingray'}

# %%
Image(filename='/content/runs/detect/train/train_batch0.jpg',width=1000)

# %%
Image(filename='/content/runs/detect/train/val_batch0_labels.jpg',width=1000)

# %%
results = model.predict(source='/content/Aquarium_Data/test/images/', save=True)
# Out:
# image 1/63 /content/Aquarium_Data/test/images/IMG_2289_jpeg_jpg.rf.fe2a7a149e7b11f2313f5a7b30386e85.jpg: 416x320 1 puffin, 98.0ms
# image 2/63 /content/Aquarium_Data/test/images/IMG_2301_jpeg_jpg.rf.2c19ae5efbd1f8611b5578125f001695.jpg: 416x320 14 penguins, 8.6ms
# image 3/63 /content/Aquarium_Data/test/images/IMG_2319_jpeg_jpg.rf.6e20bf97d17b74a8948aa48776c40454.jpg: 416x320 7 penguins, 14.2ms
# image 4/63 /content/Aquarium_Data/test/images/IMG_2347_jpeg_jpg.rf.7c71ac4b9301eb358cd4a832844dedcb.jpg: 416x320 1 penguin, 8.8ms
# image 5/63 /content/Aquarium_Data/test/images/IMG_2354_jpeg_jpg.rf.396e872c7fb0a95e911806986995ee7a.jpg: 416x320 5 penguins, 8.8ms
# image 6/63 /content/Aquarium_Data/test/images/IMG_2371_jpeg_jpg.rf.54505f60b6706da151c164188c305849.jpg: 416x320 4 fishs, 8.3ms
# image 7/63 /content/Aquarium_Data/test/images/IMG_2379_jpeg_jpg.rf.7dc3160c937072d26d4624c6c48e904d.jpg: 416x320 1 fish, 9.5ms
# ...

# %%
print(type(results), len(results))
# Out:
# <class 'list'> 63

# %%
import glob
import random
from IPython.display import Image, display

image_name = random.choice(glob.glob('/content/runs/detect/train2/*.jpg'))
display(Image(filename=image_name))
