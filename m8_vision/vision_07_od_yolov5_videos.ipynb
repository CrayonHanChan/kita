# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# https://www.youtube.com/watch?v=NcaGFp76BTY

# %%
import os, time, random
import numpy as np
import pandas as pd
import cv2, torch
from tqdm.auto import tqdm
import shutil as sh

from IPython.display import Video, HTML
from base64 import b64encode # 이진 파일(예: 비디오 파일)을 텍스트 형식으로 변환하여 HTML 문서나 소스 코드 내에 직접 포함시킬 수 있게 해줌

# %%
# %%time

# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U pycocotools # 데이터를 저장하는 방식인 COCO Data format과, 이를 불러오고 사용할 때 유용한 COCO API인 Pycocotools
# !pip install -qr yolov5/requirements.txt  # install dependencies
# !cp yolov5/requirements.txt ./
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16525, done.
# remote: Total 16525 (delta 0), reused 0 (delta 0), pack-reused 16525
# Receiving objects: 100% (16525/16525), 15.06 MiB | 8.95 MiB/s, done.
# Resolving deltas: 100% (11359/11359), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.1/749.1 kB 49.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 56.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 63.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 86.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# drive  requirements.txt  sample_data  yolov5

# %%
# !python yolov5/detect.py --source https://www.youtube.com/watch?v=NcaGFp76BTY --weights yolov5s.pt --conf 0.25
# Out:
# detect: weights=['yolov5s.pt'], source=https://www.youtube.com/watch?v=NcaGFp76BTY, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 321MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# requirements: Ultralytics requirements ['pafy', 'youtube_dl==2020.12.2'] not found, attempting AutoUpdate...
# ...

# %%
# path at the end of the detection process "Results saved to yolov5/runs/detect/exp"
filenames = ''
for (filenames) in os.walk("/content/yolov5/runs/detect/exp"):
    # we are expecting one file as we processed one video
    filename = filenames
    print(filenames)
# Out:
# ('/content/yolov5/runs/detect/exp', [], ['watch_v_NcaGFp76BTY.mp4'])

# %%
ls
# Out:
# drive/  requirements.txt  sample_data/  yolov5/  yolov5s.pt

# %% [markdown]
# shutil을 이용한 파일 복사
#
# https://zephyrus1111.tistory.com/199

# %%
import shutil
# video will be copied into kaggle/working directory it's eaisier to download it and check the results
shutil.copy('/content/yolov5/runs/detect/exp/watch_v_NcaGFp76BTY.mp4', '/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/output.mp4')
# Out:
# '/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/output.mp4'

# %% [markdown]
# 다른 유튜브 영상으로 실습(자동차)
# - https://www.youtube.com/watch?v=A0V1PtUz5Ik

# %%
# !python yolov5/detect.py --source https://www.youtube.com/watch?v=A0V1PtUz5Ik --weights yolov5s.pt --conf 0.25
# Out:
# detect: weights=['yolov5s.pt'], source=https://www.youtube.com/watch?v=A0V1PtUz5Ik, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# 1/1: https://www.youtube.com/watch?v=A0V1PtUz5Ik...  Success (496 frames 1280x720 at 24.00 FPS)
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# ...

# %%
filenames = ''
for (filenames) in os.walk("/content/yolov5/runs/detect/exp2"):
    # we are expecting one file as we processed one video
    filename = filenames
    print(filenames)
# Out:
# ('/content/yolov5/runs/detect/exp2', [], ['watch_v_A0V1PtUz5Ik.mp4'])

# %%
ls
# Out:
# drive/  requirements.txt  sample_data/  yolov5/  yolov5s.pt

# %%
import shutil
# video will be copied into kaggle/working directory it's eaisier to download it and check the results
shutil.copy('/content/yolov5/runs/detect/exp2/watch_v_A0V1PtUz5Ik.mp4', '/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/output_2.mp4')
# Out:
# '/content/drive/MyDrive/hjh_kita_directory/Github/kita_231026/m8_vision/output_2.mp4'
